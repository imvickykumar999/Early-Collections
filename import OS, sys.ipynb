# %%
# https://realpython.com/working-with-files-in-python/

import os
type(os)
# Out:
# module

# %%
type(os.name)
# Out:
# str

# %%
os.name
# Out:
# 'nt'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Vicky Kumar\\Desktop\\Program Output\\Jupyter Notebook'

# %%
# os.rmdir('...mkdir')
# os.rmdir('...py_tut')
os.listdir()
# Out:
# ['.google-cookie',
#  '.ipynb_checkpoints',
#  'CancerByKNN by shivam boss.ipynb',
#  'CancerByLogistic by shivam boss.ipynb',
#  'Crop image using pillow.ipynb',
#  'dataframe.ipynb',
#  'dataset',
#  'emotion detection.ipynb',
#  'Excel Sheet.ipynb',
#  'Extract images from video.ipynb',
#  'face detection testing mode 2nd time.ipynb',
#  'Face Detector FINAL PROJECT.ipynb',
#  'Face detector vicky ID match.ipynb',
#  'face recognition geekforgeeks.ipynb',
#  'Face recognition Vicky.ipynb',
#  'Facial Expression .ipynb',
#  'Flask.ipynb',
#  'Fraud Credit card Detection stuti mittra boss github.ipynb',
#  'Front face.ipynb',
#  'github face recognition.ipynb',
#  'image to text and then to speech.ipynb',
#  'import OS.ipynb',
#  'keras.ipynb',
#  'Linear Regression with plotting.ipynb',
#  'load_iris.ipynb',
#  'MNIST.ipynb',
#  'MOTION Detector.ipynb',
#  'Multiple Face Recognition using dlib.ipynb',
#  'Music Player.ipynb',
#  'mydatabase.db',
#  'myfile.txt',
# ...

# %%
os.mkdir('...py_tut')
os.listdir()
# Out:
# ['...py_tut',
#  '.google-cookie',
#  '.ipynb_checkpoints',
#  'CancerByKNN by shivam boss.ipynb',
#  'CancerByLogistic by shivam boss.ipynb',
#  'Crop image using pillow.ipynb',
#  'dataframe.ipynb',
#  'dataset',
#  'emotion detection.ipynb',
#  'Excel Sheet.ipynb',
#  'Extract images from video.ipynb',
#  'face detection testing mode 2nd time.ipynb',
#  'Face Detector FINAL PROJECT.ipynb',
#  'Face detector vicky ID match.ipynb',
#  'face recognition geekforgeeks.ipynb',
#  'Face recognition Vicky.ipynb',
#  'Facial Expression .ipynb',
#  'Flask.ipynb',
#  'Fraud Credit card Detection stuti mittra boss github.ipynb',
#  'Front face.ipynb',
#  'github face recognition.ipynb',
#  'image to text and then to speech.ipynb',
#  'import OS.ipynb',
#  'keras.ipynb',
#  'Linear Regression with plotting.ipynb',
#  'load_iris.ipynb',
#  'MNIST.ipynb',
#  'MOTION Detector.ipynb',
#  'Multiple Face Recognition using dlib.ipynb',
#  'Music Player.ipynb',
#  'mydatabase.db',
#  'myfile.txt',
# ...

# %%
os.rename('...py_tut','...mkdir')
os.listdir()
# Out:
# ['...mkdir',
#  '.google-cookie',
#  '.ipynb_checkpoints',
#  'CancerByKNN by shivam boss.ipynb',
#  'CancerByLogistic by shivam boss.ipynb',
#  'Crop image using pillow.ipynb',
#  'dataframe.ipynb',
#  'dataset',
#  'emotion detection.ipynb',
#  'Excel Sheet.ipynb',
#  'Extract images from video.ipynb',
#  'face detection testing mode 2nd time.ipynb',
#  'Face Detector FINAL PROJECT.ipynb',
#  'Face detector vicky ID match.ipynb',
#  'face recognition geekforgeeks.ipynb',
#  'Face recognition Vicky.ipynb',
#  'Facial Expression .ipynb',
#  'Flask.ipynb',
#  'Fraud Credit card Detection stuti mittra boss github.ipynb',
#  'Front face.ipynb',
#  'github face recognition.ipynb',
#  'image to text and then to speech.ipynb',
#  'import OS.ipynb',
#  'keras.ipynb',
#  'Linear Regression with plotting.ipynb',
#  'load_iris.ipynb',
#  'MNIST.ipynb',
#  'MOTION Detector.ipynb',
#  'Multiple Face Recognition using dlib.ipynb',
#  'Music Player.ipynb',
#  'mydatabase.db',
#  'myfile.txt',
# ...

# %%
os.rmdir('...mkdir')
os.listdir()
# Out:
# ['.google-cookie',
#  '.ipynb_checkpoints',
#  'CancerByKNN by shivam boss.ipynb',
#  'CancerByLogistic by shivam boss.ipynb',
#  'Crop image using pillow.ipynb',
#  'dataframe.ipynb',
#  'dataset',
#  'emotion detection.ipynb',
#  'Excel Sheet.ipynb',
#  'Extract images from video.ipynb',
#  'face detection testing mode 2nd time.ipynb',
#  'Face Detector FINAL PROJECT.ipynb',
#  'Face detector vicky ID match.ipynb',
#  'face recognition geekforgeeks.ipynb',
#  'Face recognition Vicky.ipynb',
#  'Facial Expression .ipynb',
#  'Flask.ipynb',
#  'Fraud Credit card Detection stuti mittra boss github.ipynb',
#  'Front face.ipynb',
#  'github face recognition.ipynb',
#  'image to text and then to speech.ipynb',
#  'import OS.ipynb',
#  'keras.ipynb',
#  'Linear Regression with plotting.ipynb',
#  'load_iris.ipynb',
#  'MNIST.ipynb',
#  'MOTION Detector.ipynb',
#  'Multiple Face Recognition using dlib.ipynb',
#  'Music Player.ipynb',
#  'mydatabase.db',
#  'myfile.txt',
# ...

# %%
# import os module 
import os

# change the current working directory 
# to specified path 
os.chdir(r'C:\Users\Vicky Kumar\Desktop\Experiments\image to text') 

# varify the path using getcwd() 
cwd = os.getcwd() 

# print the current directory 
print("Current working directory is:", cwd) 

# os.rmdir('123vicky')
os.listdir()
# Out:
# Current working directory is: C:\Users\Vicky Kumar\Desktop\Experiments\image to text
# ['abc.txt',
#  'ankit ques.jpg',
#  'sample_bold.xls',
#  'sample_red.xls',
#  'tesseract-master',
#  'test file.txt',
#  'tts.txt',
#  'xlwt example.csv',
#  'xlwt example.xls']

# %%
# Python program to explain shutil.move() method 

# importing os module 
import os 

# importing shutil module 
import shutil 

# path 
path = r'C:\Users\Vicky Kumar\Desktop\Pafy Download'

# List files and directories 
# in 'C:\Users\Vicky Kumar\Desktop\Pafy Download' 
print("Before moving file:") 
print(os.listdir(path)) 


# Source path 
source = r'C:\Users\Vicky Kumar\Desktop\Pafy Download'

# Destination path 
destination = r'C:\Users\Vicky Kumar\Videos\Pafy\Playlist'

# Move the content of 
# source to destination 
dest = shutil.move(source, destination) 

# List files and directories 
# in "C:\Users\Vicky Kumar\Desktop\Pafy Download" 
print("After moving file:") 
print(os.listdir(path)) 

# Print path of newly 
# created file 
print("Destination path:", dest)
# Out:
# Before moving file:
# ['Ariana Grande - Side to Side - Sexy Bike Riding Version.mp4', 'Din Chadta Hai Dar Lagta Hai   Shweta Prasad, Makdee Song.mp4', 'Do Me A Favour Lets Play Holi Whatsapp Status _ Waqt _ Akshay, Priyanka.mp4', 'Holiya Me ude Rang Lal Lal re ( होलिया में उड़े रंग लाल लाल रे ) Whatsapp status.mp4', 'Indila - Dernière Danse [Cover by Ester Peony].mp4', 'Major Lazer – Light it Up (feat. Nyla & Fuse ODG) (Music Video Remix) by Method Studios.mp4']
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\Anaconda3\lib\shutil.py in move(src, dst, copy_function)
#     565     try:
# --> 566         os.rename(src, real_dst)
#     567     except OSError:
#
# PermissionError: [WinError 5] Access is denied: 'C:\\Users\\Vicky Kumar\\Desktop\\Pafy Download' -> 'C:\\Users\\Vicky Kumar\\Videos\\Pafy\\Playlist\\Pafy Download'
#
# ...

# %%
with open(r'C:\Users\Vicky Kumar\Desktop\Experiments\image to text\test file.txt', 'w') as f:
    data = 'some data to be written to the file'
    f.write(data)
    
# data

# %%
import os

b = os.getcwd()
print(b)

os.chdir(r'C:\Users\Vicky Kumar\Desktop\Program Output\Jupyter Notebook') 

# varify the path using getcwd() 
a = os.getcwd() 
print(a)

# print the current directory 
print("Current working directory is:", a) 

# os.rmdir('123vicky')
os.listdir()
# Out:
# C:\Users\Vicky Kumar\Desktop\Program Output\Jupyter Notebook
# C:\Users\Vicky Kumar\Desktop\Program Output\Jupyter Notebook
# Current working directory is: C:\Users\Vicky Kumar\Desktop\Program Output\Jupyter Notebook
# ['.google-cookie',
#  '.ipynb_checkpoints',
#  'CancerByKNN by shivam boss.ipynb',
#  'CancerByLogistic by shivam boss.ipynb',
#  'Crop image using pillow.ipynb',
#  'dataframe.ipynb',
#  'dataset',
#  'emotion detection.ipynb',
#  'Excel Sheet.ipynb',
#  'Extract images from video.ipynb',
#  'face detection testing mode 2nd time.ipynb',
#  'Face Detector FINAL PROJECT.ipynb',
#  'Face detector vicky ID match.ipynb',
#  'face recognition geekforgeeks.ipynb',
#  'Face recognition Vicky.ipynb',
#  'Facial Expression .ipynb',
#  'Flask.ipynb',
#  'Fraud Credit card Detection stuti mittra boss github.ipynb',
#  'Front face.ipynb',
#  'github face recognition.ipynb',
#  'image to text and then to speech.ipynb',
#  'import OS.ipynb',
#  'keras.ipynb',
# ...

# %%
# Python program to explain os.mkdir() method 
	
# importing os module 
import os 

# path 
path = r"C:\Users\Vicky Kumar\Desktop\Experiments\GeeksForGeeks"

# Create the directory 
# 'GeeksForGeeks' in 
# '/home/User/Documents' 
try: 
	os.mkdir(path) 
except OSError as error: 
	print(error)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\Vicky Kumar\\Desktop\\Experiments\\GeeksForGeeks'

# %%
# Python program to explain os.mkdir() method 

# importing os module 
import os 

# Directory 
directory = "GeeksForGeeks"

# Parent Directory path 
parent_dir = r"C:\Users\Vicky Kumar\Desktop\Experiments"

# Path 
path = os.path.join(parent_dir, directory) 

# Create the directory 
# 'GeeksForGeeks' in 
# '/home / User / Documents' 

# os.mkdir(path)
# os.mkdir(r'C:\Users\Vicky Kumar\Desktop\Experiments\GeeksForGeeks\test_dir') 

try: 
    os.mkdir(path)
    print("Directory '%s' created " %directory)
    
except OSError as error: 
    print(error)
    

# if directory / file that 
# is to be created already 
# exists then 'FileExistsError' 
# will be raised by os.mkdir() method 

# Similarly, if the specified path 
# is invalid 'FileNotFoundError' Error 
# will be raised
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\Vicky Kumar\\Desktop\\Experiments\\GeeksForGeeks'

# %%
path
# Out:
# 'C:\\Users\\Vicky Kumar\\Desktop\\Experiments\\GeeksForGeeks'

# %%
import os

def k(ch):
    try:
        g = int(input('dir no. '))
        directory = 'dir_no' + str(g)
        path = os.path.join(parent_dir, directory)
        
        if ch == 1:
            os.mkdir(path)
            ed = 'created'
        elif ch == 2:
            os.rmdir(path)
            ed = 'removed'
            
        print("Directory " + str(directory) + " is " + str(ed))

    except OSError as error:
        print(error)

# parent_dir = r'C:\Users\Vicky Kumar\Desktop\Experiments\GeeksForGeeks'
parent_dir = input('Enter Present Directory : ')

# x = int(input('How many loops ? : '))
# for i in range(x):
more = 1
while more == 1:
    ch = int(input('\n1). make dir\n2). remove dir\n'))
    k(ch)
    more = int(input("More ? (1/0) : "))
    if more is not 1:
        print('...thanks for using this code ;)')
        break
# Out:
# Enter Present Directory : 8
#
# 1). make dir
# 2). remove dir
# 9
# dir no. 8
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-5-87e3bd14b9d8> in <module>
#      27 while more == 1:
#      28     ch = int(input('\n1). make dir\n2). remove dir\n'))
# ---> 29     k(ch)
#      30     more = int(input("More ? (1/0) : "))
#      31     if more is not 1:
#
# <ipython-input-5-87e3bd14b9d8> in k(ch)
#      14             ed = 'removed'
#      15
# ---> 16         print("Directory " + str(directory) + " is " + str(ed))
#      17
#      18     except OSError as error:
#
# UnboundLocalError: local variable 'ed' referenced before assignment

# %%
k = os.mkdir(path)
type(k)
# Out:
# NoneType

# %%
type(os.rmdir(path))
# Out:
# NoneType

# %%
import os
import shutil
for i in range(10):
    directory = 'dir_no ' + str(i+1)
    path = os.path.join(r'C:\Users\Vicky Kumar\Desktop\Experiments\GeeksForGeeks', directory)
    try:
        if not os.path.exists(path):
            os.mkdir(path)
            directories = 'file_no ' + str(i+1)
            paths = os.path.join(path, directories)
            file1 = open(paths + str(i+1) + ".txt","a") #write mode 
            file1.write(str(i+1)) 
            file1.close()
        else:
    #         os.rmdir(path) # use to delete directory when it is already empty
            shutil.rmtree(path) # it can be used even when directory is not empty
        
    except OSError as error:
        print(error)

# for i in range(10):
#     # Write-Overwrites 
#     file1 = open(r"C:\Users\Vicky Kumar\Desktop\Experiments\GeeksForGeeks\abc" + str(i+1) + ".txt","w") #write mode 
#     file1.write(str(i+1)) 
#     file1.close()

# %%
# import os,sys,string
# from random import choice

# lst = [i for i in string.ascii_lowercase]

# try:
# 	os.mkdir("E:\\folder_forest")

# os.chdir("E\\folder_forest")

# # make folder
# def folder():
# 	for i in lst:
# 		os.mkdir(i)

# folder()

# for i in os.listdir():
# 	os.chdir(i)
# 	folder()
# 	for j in os.listdir():
# 		os.chdir(j)
# 		folder()
# 		for k in os.listdir():
# 			os.chdir(k)
# 			folder()
# 			for l in os.listdir():
# 				os.chdir(l)
# 				folder()
# 				for m in os.listdir():
# 					os.chdir(m)
# 					folder()
# 					for n in os.listdir():
# 						os.chdir(n)
# 						folder()
# 						for o in os.listdir():
# 							os.chdir(o)
# 							folder()
# 							os.chdir('../')
# 						os.chdir('../')
# 					os.chdir('../')
# 				os.chdir('../')
# 			os.chdir('../')
# 		os.chdir('../')
# 	os.chdir('../')

# %%
import os

# C:\Users\Vicky Kumar\Videos\SnaptubeVideosandMP3
path = os.path.join(r'C:\Users', os.getlogin(), )
path, ls
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ef9026a7f98b> in <module>
#       3 # C:\Users\Vicky Kumar\Videos\SnaptubeVideosandMP3
#       4 path = os.path.join(r'C:\Users', os.getlogin(), )
# ----> 5 path, ls
#
# NameError: name 'ls' is not defined

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 4A42-9E62
#
#  Directory of C:\Users\Vicky Kumar
#
# 30-Mar-20  09:11 PM    <DIR>          .
# 30-Mar-20  09:11 PM    <DIR>          ..
# 05-Jan-20  11:28 PM    <DIR>          .anaconda
# 06-Jan-20  12:36 AM    <DIR>          .android
# 06-Jan-20  12:36 AM    <DIR>          .AndroidStudio3.5
# 09-Feb-20  06:54 PM               676 .bash_history
# 02-Feb-20  05:12 AM    <DIR>          .cache
# 05-Jan-20  11:20 PM    <DIR>          .conda
# 24-Mar-20  08:05 PM                43 .condarc
# 02-Feb-20  12:58 AM    <DIR>          .config
# 08-Dec-19  04:17 PM    <DIR>          .dotnet
# 09-Feb-20  05:51 PM               243 .gitconfig
# 05-Jan-20  09:25 PM    <DIR>          .idea
# 05-Feb-20  12:38 PM    <DIR>          .idlerc
# 19-Feb-20  10:36 PM    <DIR>          .ipynb_checkpoints
# 05-Jan-20  11:51 PM    <DIR>          .ipython
# 05-Jan-20  11:57 PM    <DIR>          .jupyter
# 01-Feb-20  05:16 PM    <DIR>          .keras
# ...

# %%
import os
from PIL import Image

path = os.path.join('C:\\Users', os.getlogin())
c = 1

for x in os.listdir(path):
    print(c, x)
    c += 1

_dir = input('Enter Directory : ')
path = os.path.join(path, _dir)

_dir = os.listdir(path)

for i in _dir:
    print(i)
# Out:
# 1 .anaconda
# 2 .android
# 3 .AndroidStudio3.5
# 4 .bash_history
# 5 .cache
# 6 .conda
# 7 .condarc
# 8 .config
# 9 .dotnet
# 10 .gitconfig
# 11 .idea
# 12 .idlerc
# 13 .ipynb_checkpoints
# 14 .ipython
# 15 .jupyter
# 16 .keras
# 17 .matplotlib
# 18 .node_repl_history
# 19 .pipwin
# 20 .PyCharm2019.2
# 21 .python_history
# 22 .VirtualBox
# 23 .vscode
# 24 1 min song 😗😙 neha kakkar ❤-H-to53jtE5M.mp4
# 25 3D Objects
# 26 Anaconda3
# 27 ansel
# 28 AppData
# 29 Application Data
# 30 Arduino .ipynb
# 31 arduino-1.8.10-windows.exe
# 32 build
# 33 Code block programme
# 34 Contacts
# 35 Cookies
# 36 database.db
# 37 Desktop
# 38 dist
# 39 Documents
# 40 Downloads
# 41 Face cascade.ipynb
# 42 face.spec
# 43 Favorites
# 44 GoogleMapPlotter.ipynb
# 45 GTA V Theme - Welcome To Los Santos Cover-h8XCz11suvU.mp4
# 46 Instabot.ipynb
# 47 Instagram upload file.ipynb
# 48 instapy.ipynb
# 49 Links
# 50 Local Settings
# 51 Microsoft
# 52 MicrosoftEdgeBackups
# 53 miktex-console.lock
# 54 Music
# ...

# %%
path = os.path.join('C:\\Users', os.getlogin(), 'Videos', 'SnaptubeVideosandMP3')
for _ in os.listdir(path):
    print(_)
# Out:
# 682997f33f59406d8c6cd23c3cbb53ff.mp4
# 6e6dc55d20884207bb01a897844b44ff.mp4
# 70_s Romantic Mashup _ Varsha Tripathi ft. Abhay J(360P).mp4
# Aag Lage Chahe Basti Mai _ OFFICIAL VIDEO _ SIRAZE(360P).mp4
# Aankhon mein tera hi chehra (Tera Deewana)_ cover(360P).mp4
# Aari Thi Marjani Va Bandook Banke आरी थी मरजानी वा बंदूक बनके Video.mp4
# AIB _ Udd Gaye by RITVIZ [Official Music Video] _ #BacardiHousePartySessions.mp4
# Alan Walker - Faded(360P).mp4
# Alan Walker, Sabrina Carpenter & Farruko  - On My Way - YouTube.mp4
# Alessia Cara - Scars To Your Beautiful.mp4
# Arabic song funny(480P).mp4
# Arabs Got Talent -  المغرب - هبة(360P).mp4
# Ariana Grande - no tears left to cry(360P).mp4
# Ariana Grande - Side to Side - Sexy Bike Riding Version.mp4
# Ariana Grande - Side to Side - Sexy Bike Riding Version_Trim.mp4
# Baby Ariel - _Aww_ [Official Music Video](360P).mp4
# Badal aavara dj(480P).mp4
# Badal aavara(360P).mp4
# Badshah - Mercy feat. Lauren Gottlieb_ Lyrics Vide(360P).mp4
# ...

# %%
import os
import pytesseract
from PIL import Image
import pyttsx3
from googletrans import Translator

p = Translator()
engine = pyttsx3.init()
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files (x86)\Tesseract-OCR\tesseract.exe'

path = os.path.join('C:\\Users', os.getlogin(), 'Pictures', 'Saved Pictures')
if not os.path.exists(path):
    os.mkdir(path)

directory = os.listdir(path)
sno = 1
print()
for image in directory:
    print(sno, image)
    sno += 1
    
os.startfile(path)
more = '1'
while more is not '0':
    
    index = int(input('\nWhich Image index : ')) - 1
    file = os.path.join(path, directory[index])
    print('\nCURRENT Image... ' + directory[index])
    text = pytesseract.image_to_string(file)
    print('Text in Image...\n\n' + text)
    os.startfile(file)
    
    k = p.translate(text, dest='hi')
    print()
    e = str(k)
    trans = e[33:-49]
    print('Translated Text in Image...\n\n' + trans)
    
    engine.say(trans)
    engine.runAndWait()

    more = input('See another? (1/0) : ')
else:
    print('\nLook @ it...')
# Out:
# 1 10-Median-Blur.png
# 2 23-Color-detected.png
# 3 Annotation 2020-03-14 101055.png
# 4 Annotation 2020-03-20 125751.png
# 5 Annotation 2020-03-20 181619.png
# 6 Annotation 2020-03-25 085757.png
# 7 Annotation 2020-03-27 172619.png
# 8 Annotation 2020-03-31 154543.png
# 9 Annotation 2020-04-01 152422.png
# 10 Annotation 2020-04-01 194710.png
# 11 Annotation 2020-04-02 132455.png
# 12 Annotation 2020-04-02 154755.png
# 13 Annotation 2020-04-02 185715.png
# 14 arya.png
# 15 aryadp.png
# 16 aur batao.png
# 17 b05b638a1417f254b0e5b10ca217f600.html
# 18 background.png
# 19 baw.png
# 20 bawc.png
# 21 car.png
# 22 charge30.png
# 23 charging_status.png
# 24 color.png
# 25 database load.png
# 26 desktop.ini
# 27 download (1).png
# 28 download (2).png
# 29 download.png
# 30 dp.png
# 31 eye.jpg
# 32 eye.png
# 33 f59f4d4e-aaf0-484d-addf-38181b67d1b7.jpg
# 34 facial_landmarks_68markup-768x619.jpg
# 35 filter.png
# 36 fish.jpg
# 37 flip.png
# 38 gradient.png
# 39 gray.png
# 40 Helicopter.png
# ...

# %%
import os
path = os.path.join('C:\\Users', os.getlogin(), 'Desktop', 'AI training')
for file in os.listdir(path):
    os.startfile(os.path.join(path, file))

# %% [markdown]
# ## https://www.geeksforgeeks.org/python-check-if-a-file-or-directory-exists/

# %%
# Python program to demonstrate 
# sys.argv 


import sys 


print("This is the name of the program:", 
	sys.argv[0]) 
print("Number of elements including the name of the program:", 
	len(sys.argv)) 
print("Number of elements excluding the name of the program:", 
	(len(sys.argv)-1)) 
print("Argument List:", 
	str(sys.argv))
# Out:
# This is the name of the program: C:\Users\Vicky Kumar\Anaconda3\lib\site-packages\ipykernel_launcher.py
# Number of elements including the name of the program: 3
# Number of elements excluding the name of the program: 2
# Argument List: ['C:\\Users\\Vicky Kumar\\Anaconda3\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\Vicky Kumar\\AppData\\Roaming\\jupyter\\runtime\\kernel-51a643a1-43be-45c9-9073-75b85422b3a2.json']

# %%
# Python program to demonstrate 
# sys.argv 


import sys 


print("This is the name of the program:", 
	sys.argv[0]) 
print("Number of elements including the name of the program:", 
	len(sys.argv)) 
print("Number of elements excluding the name of the program:", 
	(len(sys.argv)-1)) 
print("Argument List:", 
	str(sys.argv))
# Out:
# This is the name of the program: C:\Users\Vicky Kumar\Anaconda3\lib\site-packages\ipykernel_launcher.py
# Number of elements including the name of the program: 3
# Number of elements excluding the name of the program: 2
# Argument List: ['C:\\Users\\Vicky Kumar\\Anaconda3\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\Vicky Kumar\\AppData\\Roaming\\jupyter\\runtime\\kernel-51a643a1-43be-45c9-9073-75b85422b3a2.json']

# %%
with open(sys.argv[2], 'r') as f:
    f = f.read()
    
print(f)

os.startfile(sys.argv[0])
# Out:
# {
#   "shell_port": 56836,
#   "iopub_port": 56837,
#   "stdin_port": 56838,
#   "control_port": 56840,
#   "hb_port": 56839,
#   "ip": "127.0.0.1",
#   "key": "21b58652-2dd0e00ea6b0d4bde2e29b70",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": ""
# }

# %%
# Python program to demonstrate 
# sys.argv 


import sys 

print("\nThis is the name of the program:", sys.argv[0]) 

print("\nArgument List:", str(sys.argv), end = '\n\n') 

sys.argv
# Out:
# This is the name of the program: C:\Users\Vicky Kumar\Anaconda3\lib\site-packages\ipykernel_launcher.py
#
# Argument List: ['C:\\Users\\Vicky Kumar\\Anaconda3\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\Vicky Kumar\\AppData\\Roaming\\jupyter\\runtime\\kernel-51a643a1-43be-45c9-9073-75b85422b3a2.json']
# ['C:\\Users\\Vicky Kumar\\Anaconda3\\lib\\site-packages\\ipykernel_launcher.py',
#  '-f',
#  'C:\\Users\\Vicky Kumar\\AppData\\Roaming\\jupyter\\runtime\\kernel-51a643a1-43be-45c9-9073-75b85422b3a2.json']

# %% [markdown]
# # How to use sys.argv in Python
# ## Command line arguments are those values that are passed during calling of program along with the calling statement. Thus, the first element of the array sys.argv() is the name of the program itself. sys.argv() is an array for command line arguments in Python. To employ this module named “sys” is used. sys.argv is similar to an array and the values are also retrieved like Python array.
#
# # The sys module
#
# ## The sys module provides functions and variables used to manipulate different parts of the Python runtime environment. This module provides access to some variables used or maintained by the interpreter and to functions that interact strongly with the interpreter.
#
# # https://www.geeksforgeeks.org/python-set-6-arguments/

# %%
# Python program to explain os.path.exists() method 
	
# importing os module 
import os 
	
# Specify path 
path = '/usr/local/bin/'
	
# Check whether the specified 
# path exists or not 
isExist = os.path.exists(path) 
print(isExist) 
	
	
# Specify path 
path = '/home/User/Desktop/file.txt'
	
# Check whether the specified 
# path exists or not 
isExist = os.path.exists(path) 
print(isExist)
# Out:
# False
# False

# %%
# Python program to explain os.path.isfile() method 

# importing os module 
import os 

# Path 
path = 'C:/Users/gfg/Desktop/file.txt'

# Check whether the 
# specified path is 
# an existing file 
isFile = os.path.isfile(path) 
print(isFile) 

# Path 
path = r'C:\Users\Vicky Kumar\Desktop\Grand Theft Auto V\common.rpf'

# Check whether the 
# specified path is 
# an existing file 
isFile = os.path.isfile(path) 
print(isFile)
# Out:
# False
# True

# %%
# Python program to explain os.path.isdir() method 
	
# importing os.path module 
import os.path 
	
# Path 
path = '/home/User/Documents/file.txt'
	
# Check whether the 
# specified path is an 
# existing directory or not 
isdir = os.path.isdir(path) 
print(isdir) 
	
	
# Path 
path = '/home/User/Documents/'
	
# Check whether the 
# specified path is an 
# existing directory or not 
isdir = os.path.isdir(path) 
print(isdir)
# Out:
# False
# False

# %%
# Python program to explain os.path.isdir() method 
	
# importing os.path module 
import os.path 
	
	
# Create a directory 
# (in current working directory) 
dirname = "GeeksForGeeks"
os.mkdir(os.path.join(r'C:\Users\Vicky Kumar\Desktop\Grand Theft Auto V', dirname) 
	
# Create a symbolic link 
# pointing to above directory 
symlink_path = r'C:\Users\Vicky Kumar\Desktop\Grand Theft Auto V'
os.symlink(dirname, symlink_path) 
	
	
path = dirname 
	
# Now, Check whether the 
# specified path is an 
# existing directory or not 
isdir = os.path.isdir(path) 
print(isdir) 
	
path = symlink_path 
	
# Check whether the 
# specified path (which is a 
# symbolic link ) is an 
# existing directory or not 
isdir = os.path.isdir(path) 
print(isdir) 

os.path.join(r'C:\Users\Vicky Kumar\Desktop\Grand Theft Auto V', dirname
# Out:
#   File "<ipython-input-58-536f87bddc1c>", line 23
#     isdir = os.path.isdir(path)
#         ^
# SyntaxError: invalid syntax

# %%
# Import Path class 
from pathlib import Path 
	
# Path 
path = r'C:\Users\Vicky Kumar\Desktop\Grand Theft Auto V'
	
# Instantiate the Path class 
obj = Path(path) 
	
# Check if path points to 
# an existing file or directory 
print(obj.exists()) 

obj
# Out:
# True
# WindowsPath('C:/Users/Vicky Kumar/Desktop/Grand Theft Auto V')

# %%
# Python code to demonstrate the use of 'sys' module 
# for command line arguments 

import sys 

# command line arguments are stored in the form 
# of list in sys.argv 
argumentList = sys.argv 
print (argumentList) 

# Print the name of file 
print (sys.argv[0]) 

# Print the first argument after the name of file 
print (sys.argv[1])
# Out:
# ['C:\\Users\\Vicky Kumar\\Anaconda3\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\Vicky Kumar\\AppData\\Roaming\\jupyter\\runtime\\kernel-51a643a1-43be-45c9-9073-75b85422b3a2.json']
# C:\Users\Vicky Kumar\Anaconda3\lib\site-packages\ipykernel_launcher.py
# -f

# %%
import sys 
from math import factorial 

print (factorial(int(sys.argv[1])))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-4dd202a66bdd> in <module>
#       2 from math import factorial
#       3
# ----> 4 print (factorial(int(sys.argv[1])))
#
# ValueError: invalid literal for int() with base 10: '-f'

# %%
# Python program to illustrate the use of args which 
# multiplies all the values given to the function as parameter 

def multiplyAll(*values): 
    mul = 1

    # values(args) will be in the form of tuple 
    print (values) 
    print ("Type = ", type(values))


    # Multiplying the all the parameters and return the result 
    for i in values: 
        mul = mul * i 

    return mul 


# Driver program to test above function 

# Multiply two numbers using above function 
ans = multiplyAll(1,2) 
print ("The multiplication of 1 and 2 is ", ans) 

# Multiply 5 numbers using above function 
ans = multiplyAll(3, 4, 5, 6, 7) 
print ("The multiplication of 3 to 7 is ", ans)
# Out:
# (1, 2)
# Type =  <class 'tuple'>
# The multiplication of 1 and 2 is  2
# (3, 4, 5, 6, 7)
# Type =  <class 'tuple'>
# The multiplication of 3 to 7 is  2520

# %%
# Program to illustrate the use of kwargs in Python 

# Function that print the details of a student 
# The number of details per student may vary 
def printDetails(**details): 

    # Variable 'details' contains the details in the 
    # form of dictionary 
    print ("Parameter details contains")
    print (details) 
    print ("Type = ", type(details)) 

    # Print first name 
    print ("First Name = ", details['firstName']) 

    # Print the department of student 
    print ("Department = ", details['department']) 
    print() # Extra line break 


# Driver program to test above function 

# Calling the function with three arguments 
printDetails(firstName = "Nikhil", 
            rollNumber = "007", 
            department = "CSE") 

# Calling the function with two arguments 
printDetails(firstName = "Abhay", 
            department = "ECE")
# Out:
# Parameter details contains
# {'firstName': 'Nikhil', 'rollNumber': '007', 'department': 'CSE'}
# Type =  <class 'dict'>
# First Name =  Nikhil
# Department =  CSE
#
# Parameter details contains
# {'firstName': 'Abhay', 'department': 'ECE'}
# Type =  <class 'dict'>
# First Name =  Abhay
# Department =  ECE

# %%
# Function containing both args and kwargs 
def cheeseshop(kind, *arguments, **keywords): 
    print ("-- Do you have any", kind, "?")
    print ("-- I'm sorry, we're all out of", kind) 
    for arg in arguments: 
        print (arg) 
    print ("-" * 40)
    keys = sorted(keywords.keys()) 
    for kw in keys: 
        print (kw, ":", keywords[kw]) 

# Driver program to test above function 
cheeseshop("Burger", "It's very funny, sir.", 
        "It's really very, VERY funny, sir.", 
        shopkeeper='Michael Palin', 
        client="John Cleese", 
        sketch="Cheese Shop Sketch")
# Out:
# -- Do you have any Burger ?
# -- I'm sorry, we're all out of Burger
# It's very funny, sir.
# It's really very, VERY funny, sir.
# ----------------------------------------
# client : John Cleese
# shopkeeper : Michael Palin
# sketch : Cheese Shop Sketch

# %%
import os
path = os.path.join('C:\\Users', os.getlogin(), 'Desktop', 'AI training')
for file in os.listdir(path):
    os.startfile(os.path.join(path, file))

# %%
path = os.path.join('C:\\Users', os.getlogin(), 'Desktop', 'AI training')

a = os.path.isfile(path)
b = os.path.isdir(path)
c = os.path.exists(path)

print(a, b, c, path)

direct = os.listdir(path)

for new_dir in direct:
    new_path = os.path.join(path, new_dir)
    
    d = os.path.isfile(os.path.join(new_path, new_dir))
    e = os.path.isdir((os.path.join(new_path, new_dir)))
    f = os.path.exists((os.path.join(new_path, new_dir)))

    print(d, e, f, new_dir, new_path)
# Out:
# False True True C:\Users\Vicky Kumar\Desktop\AI training
# False False False My project C:\Users\Vicky Kumar\Desktop\AI training\My project
# False False False MY WORLD C:\Users\Vicky Kumar\Desktop\AI training\MY WORLD
# False False False Other's project C:\Users\Vicky Kumar\Desktop\AI training\Other's project

# %% [markdown]
# # >>> What is St_mtime?
# # st_mtime: time of last data modification. st_ctime: time of last file status change.

# %%
import os

with os.scandir() as direct:
    for entry in direct:
        info = entry.stat()
        print(info.st_mtime)
# Out:
# 1584109702.8521059
# 1586085994.0185955
# 1585806627.6938443
# 1511186255.0
# 1585304430.1826463
# 1585381204.4245484
# 1585032825.765116
# 1578251110.718757
# 1582894728.563902
# 1585060015.8365207
# 1584109289.9276247
# 1584965993.9786165
# 1584227756.2259297
# 1585751390.0743377
# 1585207606.1130025
# 1581782925.4935975
# 1583841207.9513464
# 1582459321.8538427
# 1586071283.4638886
# 1586089761.198873
# 1585576289.2457771
# 1584518153.663932
# 1584040771.1870794
# 1585032386.4891465
# 1585371454.3305128
# 1583841011.3140168
# 1585032825.7611163
# 1585131547.7827852
# 1583824253.4355211
# 1585404203.899159
# 1585405479.6117563
# 1582188589.0287912
# 1585735894.6512108
# 1584694058.44286
# 1581773342.900258
# 1584128241.1744246
# 1584256036.134749
# 1582459983.4574997
# 1586071226.5537038
# 1581255198.799845
# 1578250808.6567116
# 1584218017.155121
# 1584226866.6174743
# 1581278387.5066516
# 1584215943.4371655
# 1586081600.605522
# 1584021150.1305084
# 1586086164.9997709
# ...

# %%
import os, os.path

for filename in os.listdir(path):
    modification_time = os.path.getmtime(os.path.join(path, filename))
    print("Last modification time since the epoch:", modification_time) 
    local_time = time.ctime(modification_time)
    print("Last modification time(Local time):", local_time) 
    print()
# Out:
# Last modification time since the epoch: 1585904054.7518992
# Last modification time(Local time): Fri Apr  3 14:24:14 2020
#
# Last modification time since the epoch: 1585895800.06975
# Last modification time(Local time): Fri Apr  3 12:06:40 2020
#
# Last modification time since the epoch: 1585896032.1199653
# Last modification time(Local time): Fri Apr  3 12:10:32 2020
#
# Last modification time since the epoch: 1585895706.6043441
# Last modification time(Local time): Fri Apr  3 12:05:06 2020
#
# Last modification time since the epoch: 1585895800.0557475
# Last modification time(Local time): Fri Apr  3 12:06:40 2020
#
# Last modification time since the epoch: 1585896031.9779577
# Last modification time(Local time): Fri Apr  3 12:10:31 2020

# %%
# Python program to explain os.path.getmtime() method 
	
# importing os and time module 
import os 
import time 

# Path 
path = os.path.join('C:\\Users', os.getlogin(), 'Desktop', 'Experiments', 'physics exe')
# C:\Users\Vicky Kumar\Desktop\Experiments\physics exe
# Get the time of last 
# modifation of the specified 
# path since the epoch 
modification_time = os.path.getmtime(path) 
print("Last modification time since the epoch:", modification_time) 

# convert the time in 
# seconds since epoch 
# to local time 
local_time = time.ctime(modification_time) 
print("Last modification time(Local time):", local_time)
# Out:
# Last modification time since the epoch: 1585896706.5739608
# Last modification time(Local time): Fri Apr  3 12:21:46 2020

# %%
from pathlib import Path
import time

for path in Path('.').iterdir():
    info = path.stat()
    print(time.ctime(info.st_mtime))
# Out:
# Fri Mar 13 19:58:22 2020
# Sun Apr  5 16:56:34 2020
# Thu Apr  2 11:20:27 2020
# Mon Nov 20 19:27:35 2017
# Fri Mar 27 15:50:30 2020
# Sat Mar 28 13:10:04 2020
# Tue Mar 24 12:23:45 2020
# Mon Jan  6 00:35:10 2020
# Fri Feb 28 18:28:48 2020
# Tue Mar 24 19:56:55 2020
# Fri Mar 13 19:51:29 2020
# Mon Mar 23 17:49:53 2020
# Sun Mar 15 04:45:56 2020
# Wed Apr  1 19:59:50 2020
# Thu Mar 26 12:56:46 2020
# Sat Feb 15 21:38:45 2020
# Tue Mar 10 17:23:27 2020
# Sun Feb 23 17:32:01 2020
# Sun Apr  5 12:51:23 2020
# Sun Apr  5 17:59:21 2020
# Mon Mar 30 19:21:29 2020
# Wed Mar 18 13:25:53 2020
# Fri Mar 13 00:49:31 2020
# Tue Mar 24 12:16:26 2020
# Sat Mar 28 10:27:34 2020
# Tue Mar 10 17:20:11 2020
# Tue Mar 24 12:23:45 2020
# Wed Mar 25 15:49:07 2020
# Tue Mar 10 12:40:53 2020
# Sat Mar 28 19:33:23 2020
# Sat Mar 28 19:54:39 2020
# Thu Feb 20 14:19:49 2020
# Wed Apr  1 15:41:34 2020
# Fri Mar 20 14:17:38 2020
# Sat Feb 15 18:59:02 2020
# Sat Mar 14 01:07:21 2020
# Sun Mar 15 12:37:16 2020
# ...

# %% [markdown]
# # Rename file location

# %%
import os
import datetime

old_path, new_path = new_path, old_path

Current_Date = datetime.datetime.today().strftime ('%d-%b-%Y')
old_path = r'C:\Users\Vicky Kumar\Desktop\Experiments\read and write in file\tts.txt'
new_path = r'C:\Users\Vicky Kumar\Desktop\Experiments\read and write in file\HTML\text to speech ' + str(Current_Date) + '.txt'

# old_path, new_path = new_path, old_path

os.rename(old_path, new_path)
os.startfile(new_path)

# %%
import os

def list_files(startpath):
    for root, dirs, files in os.walk(startpath):
        level = root.replace(startpath, '').count(os.sep)
        indent = ' ' * 4 * (level)
        print('{}{}/'.format(indent, os.path.basename(root)))
        subindent = ' ' * 4 * (level + 1)
        for f in files:
            print('{}{}'.format(subindent, f))

# %% [markdown]
# # OS. walk() generate the file names in a directory tree by walking the tree either top-down or bottom-up.
# ## For each directory in the tree rooted at directory top (including top itself), it yields a 3-tuple (dirpath, dirnames, filenames).
#
# # Description
# ### Python method walk() generates the file names in a directory tree by walking the tree either top-down or bottom-up.
#
# # Syntax
# ### Following is the syntax for walk() method −
#
# ### os.walk(top[, topdown=True[, onerror=None[, followlinks=False]]])
# # Parameters
# ### top − Each directory rooted at directory, yields 3-tuples, i.e., (dirpath, dirnames, filenames)
#
# ### topdown − If optional argument topdown is True or not specified, directories are scanned from top-down. If topdown is set to False, directories are scanned from bottom-up.
#
# ### onerror − This can show error to continue with the walk, or raise the exception to abort the walk.
#
# ### followlinks − This visits directories pointed to by symlinks, if set to true.
#
# # Return Value
# ### This method returns value.

# %%
# !/usr/bin/python

import os
path = r'C:\Users\Vicky Kumar\Desktop\Experiments\physics exe\dist\physics\etc'
i=1
for path, dirs, files in os.walk(path, topdown=False):
    print()
    print('name in files...')
    for name in files:
        print(i, os.path.join(path, name))
        i += 1
    print()
    print('name in dirs...')
    for name in dirs:
        print(i, os.path.join(path, name))
        i += 1
        
print('\n\n...total files in ', path, 'is', i-1)
# Out:
# name in files...
# 1 C:\Users\Vicky Kumar\Desktop\Experiments\physics exe\dist\physics\etc\jupyter\jupyter_notebook_config.d\jupyter-server-proxy-serverextension.json
#
# name in dirs...
#
# name in files...
# 2 C:\Users\Vicky Kumar\Desktop\Experiments\physics exe\dist\physics\etc\jupyter\nbconfig\notebook.d\widgetsnbextension.json
#
# name in dirs...
#
# name in files...
# 3 C:\Users\Vicky Kumar\Desktop\Experiments\physics exe\dist\physics\etc\jupyter\nbconfig\tree.d\jupyter-server-proxy-nbextension.json
#
# name in dirs...
#
# name in files...
#
# name in dirs...
# 4 C:\Users\Vicky Kumar\Desktop\Experiments\physics exe\dist\physics\etc\jupyter\nbconfig\notebook.d
# 5 C:\Users\Vicky Kumar\Desktop\Experiments\physics exe\dist\physics\etc\jupyter\nbconfig\tree.d
#
# name in files...
# 6 C:\Users\Vicky Kumar\Desktop\Experiments\physics exe\dist\physics\etc\jupyter\migrated
#
# name in dirs...
# ...

# %%
from pathlib import Path
from itertools import islice

space =  '    '

branch = '│   '

tee =    '├── '

last =   '└── '

i = 32294

def tree(dir_path: Path, level: int=-1, limit_to_directories: bool=False, length_limit: int= i-1):
    """Given a directory Path object print a visual tree structure"""
    dir_path = Path(dir_path) # accept string coerceable to Path
    files = 0
    directories = 0
    
    def inner(dir_path: Path, prefix: str='', level=-1):
        nonlocal files, directories
        
        if not level: 
            return # 0, stop iterating
        if limit_to_directories:
            contents = [d for d in dir_path.iterdir() if d.is_dir()]
        else: 
            contents = list(dir_path.iterdir())
        pointers = [tee] * (len(contents) - 1) + [last]
        
        for pointer, path in zip(pointers, contents):
            if path.is_dir():
                yield prefix + pointer + path.name
                directories += 1
                extension = branch if pointer == tee else space 
                yield from inner(path, prefix=prefix+extension, level=level-1)
            elif not limit_to_directories:
                yield prefix + pointer + path.name
                files += 1
                
    print(dir_path.name)
    iterator = inner(dir_path, level=level)
    
    for line in islice(iterator, length_limit):
        print(line)
    if next(iterator, None):
        print(f'... length_limit, {length_limit}, reached, counted:')
    print(f'\n{directories} directories' + (f', {files} files' if files else ''))

# =========================================================>>>>>>>>>>> need to EDIT as per directory...
path = r'C:\Users\Vicky Kumar\Desktop\Experiments\physics exe\dist\physics\etc'

# And now we can get the same sort of output as tree:
tree(Path.home() / path)

# open file location
os.startfile(path)
# Out:
# etc
# └── jupyter
#     ├── jupyter_notebook_config.d
#     │   └── jupyter-server-proxy-serverextension.json
#     ├── migrated
#     └── nbconfig
#         ├── notebook.d
#         │   └── widgetsnbextension.json
#         └── tree.d
#             └── jupyter-server-proxy-nbextension.json
#
# 5 directories, 4 files
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-29d55cd2b5f9> in <module>
#      55
#      56 # open file location
# ---> 57 os.startfile(path)
#
# NameError: name 'os' is not defined

# %%
os.path.join(Path.home(), 'Desktop')
# Out:
# 'C:\\Users\\Vicky Kumar\\Desktop'

# %% [markdown]
# # https://www.geeksforgeeks.org/use-yield-keyword-instead-return-keyword-python/

# %% [markdown]
# # >>> When to use yield instead of return in Python?
# ## The yield statement suspends function’s execution and sends a value back to the caller, but retains enough state to enable function to resume where it is left off. When resumed, the function continues execution immediately after the last yield run. This allows its code to produce a series of values over time, rather than computing them at once and sending them back like a list.

# %%
# A Simple Python program to demonstrate working 
# of yield 

# A generator function that yields 1 for the first time, 
# 2 second time and 3 third time 
def simpleGeneratorFun(): 
	yield 1
	yield 2
	yield 3

# Driver code to check above generator function 
for value in simpleGeneratorFun(): 
	print(value)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ## Return sends a specified value back to its caller whereas Yield can produce a sequence of values. We should use yield when we want to iterate over a sequence, but don’t want to store the entire sequence in memory.
#
# ## Yield are used in Python generators. A generator function is defined like a normal function, but whenever it needs to generate a value, it does so with the yield keyword rather than return. If the body of a def contains yield, the function automatically becomes a generator function.

# %%
# A Python program to generate squares from 1 
# to 100 using yield and therefore generator 

# An infinite generator function that prints 
# next square number. It starts with 1 
def nextSquare(): 
	i = 1; 

	# An Infinite loop to generate squares 
	while True: 
		yield i*i				 
		i += 1 # Next execution resumes 
				# from this point	 

# Driver code to test above generator 
# function 
for num in nextSquare(): 
	if num > 100: 
		break	
	print(num)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %%
from pathlib import Path
from itertools import islice
import os

space =  '    '

branch = '│   '

tee =    '├── '

last =   '└── '

i = 32294

def tree(dir_path: Path, level: int=-1, limit_to_directories: bool=False, length_limit: int= i-1):
    """Given a directory Path object print a visual tree structure"""
    dir_path = Path(dir_path) # accept string coerceable to Path
    files = 0
    directories = 0
    
    def inner(dir_path: Path, prefix: str='', level=-1):
        nonlocal files, directories
        
        if not level: 
            return # 0, stop iterating
        if limit_to_directories:
            contents = [d for d in dir_path.iterdir() if d.is_dir()]
        else: 
            contents = list(dir_path.iterdir())
        pointers = [tee] * (len(contents) - 1) + [last]
        
        for pointer, path in zip(pointers, contents):
            if path.is_dir():
                yield prefix + pointer + path.name
                directories += 1
                extension = branch if pointer == tee else space 
                yield from inner(path, prefix=prefix+extension, level=level-1)
            elif not limit_to_directories:
                yield prefix + pointer + path.name
                files += 1
                
    print(dir_path.name)
    iterator = inner(dir_path, level=level)
    
    for line in islice(iterator, length_limit):
        print(line)
    if next(iterator, None):
        print(f'... length_limit, {length_limit}, reached, counted:')
    print(f'\n{directories} directories' + (f', {files} files' if files else ''))

# =========================================================>>>>>>>>>>> need to EDIT as per directory...

path = r'C:\Users\Vicky Kumar\Desktop\Grand Theft Auto V\Trainers'
# path = input('Enter path name : ')

# And now we can get the same sort of output as tree:
tree(Path.home() / path)

# open file location
os.startfile(r'C:\Users\Vicky Kumar\Desktop\Grand Theft Auto V\Trainers\Menyoo\menyooStuff\JumpAroundMode.mp3')
# Out:
# etc
# └── jupyter
#     ├── jupyter_notebook_config.d
#     │   └── jupyter-server-proxy-serverextension.json
#     ├── migrated
#     └── nbconfig
#         ├── notebook.d
#         │   └── widgetsnbextension.json
#         └── tree.d
#             └── jupyter-server-proxy-nbextension.json
#
# 5 directories, 4 files

# %%
import os

while True:
	print('\n\n>>>>============== Welcome to Vicky\'s CMD =============<<<<')
	cmd = input('\nEnter command : ')
	os.system('cmd /k ' + cmd)

# os.system('cd Desktop')
# os.system('python tree.py')

# Anaconda Prompt is running cmd.py, which is running tree.py in nested manner...
# Out:
# >>>>============== Welcome to Vicky's CMD =============<<<<
#
# Enter command : cd desktop
#
#
# >>>>============== Welcome to Vicky's CMD =============<<<<
#
# Enter command : python cmd.py
#
#
# >>>>============== Welcome to Vicky's CMD =============<<<<
#
# Enter command : cd desktop
#
#
# >>>>============== Welcome to Vicky's CMD =============<<<<
#
# Enter command : cd Desktop
#
#
# >>>>============== Welcome to Vicky's CMD =============<<<<
#
# Enter command : pip install os
#
#
# >>>>============== Welcome to Vicky's CMD =============<<<<
#
# Enter command : cd ..
#
#
# >>>>============== Welcome to Vicky's CMD =============<<<<
#
# Enter command : cd ..
#
#
# >>>>============== Welcome to Vicky's CMD =============<<<<
#
# Enter command : cd ..
#
#
# >>>>============== Welcome to Vicky's CMD =============<<<<
#
# Enter command : cd /
#
#
# >>>>============== Welcome to Vicky's CMD =============<<<<
#
# Enter command : cd user
#
#
# ...
